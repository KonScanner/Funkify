# %% [markdown]
# # Main

# %% [markdown]
# ## **Spotify Data**

# %% [markdown]
# ### Funk Hypothesis

# %%
from Funk import Funk
a = Funk()

# %% [markdown]
# #### Initial Dataset Header

# %%
a._load_data().head(5)
# Out:
#                  track_id                                         track_name  \
# 0  6hpmTwgNCz81H2bFEREx29  Get Up I Feel Like Being Like A Sex Machine, P...
# 1  58cAopfBOtm1Sgifx99jtR                 Papa's Got A Brand New Bag - Pt. 1
# 2  39PqVnxzNG1O9So8nE55CS                                  Cold Sweat Part 1
# 3  7DSlXCe1TsCW3AWBgJ4YPp                      Out Of Sight - Single Version
# 4  4bgEXUHIrOZ2H4sz7j9RAB                   Funky Drummer - Pts.1 & 2 / Edit
#
#   track_type                      artist_name  \
# 0      track  James Brown, The Original J.B.s
# 1      track                      James Brown
# 2      track  James Brown & The Famous Flames
# 3      track                      James Brown
# 4      track                      James Brown
#
#                         album_name  popularity  danceability  energy  key  \
# 0               70's Funk Classics          59         0.833   0.661   10
# 1  The 50th Anniversary Collection          51         0.777   0.816    4
# 2                       Cold Sweat          24         0.894   0.280    7
# 3                     Out Of Sight          41         0.631   0.432    3
# 4               70's Funk Classics          42         0.710   0.652    6
#
#    loudness  ...                                   uri  duration_ms  \
# 0    -7.595  ...  spotify:track:6hpmTwgNCz81H2bFEREx29       318800
# 1    -5.198  ...  spotify:track:58cAopfBOtm1Sgifx99jtR       126040
# 2   -11.515  ...  spotify:track:39PqVnxzNG1O9So8nE55CS       144960
# 3   -11.478  ...  spotify:track:7DSlXCe1TsCW3AWBgJ4YPp       142200
# 4   -11.919  ...  spotify:track:4bgEXUHIrOZ2H4sz7j9RAB       424360
#
#    time_signature  analyzer_version  analyzer_timestamp  analyzer_time  \
# 0               4             4.0.0          1585961196       10.19606
# 1               4             4.0.0          1585810442        3.59057
# 2               4             4.0.0          1584095871        4.20239
# 3               4             4.0.0          1585975664        4.59530
# 4               4             4.0.0          1585961144       11.19500
#
#            analyzer_input_process num_samples end_of_fade_in start_of_fade_out
# 0  libvorbisfile L+R 44100->22050     7029540        0.43828         312.45932
# 1  libvorbisfile L+R 44100->22050     2779182        0.18313         119.51311
# 2  libvorbisfile L+R 44100->22050     3196368        0.36608         144.96001
# 3  libvorbisfile L+R 44100->22050     3135510        0.21084         135.19819
# 4  libvorbisfile L+R 44100->22050     9357138        0.31955         412.43283
#
# [5 rows x 29 columns]

# %% [markdown]
# #### Histogram and description of data

# %%
a._hist_plots()
# Out:
#                       mean         std        max        min         25%  \
# time_signature       3.991       0.097  4.000e+00  3.000e+00       4.000
# duration_ms     306479.258  173335.300  1.614e+06  1.260e+05  202707.000
# acousticness         0.228       0.194  8.120e-01  7.020e-04       0.081
# energy               0.674       0.150  9.890e-01  2.710e-01       0.573
# key                  5.803       3.659  1.100e+01  0.000e+00       2.000
# liveness             0.177       0.179  9.420e-01  1.650e-02       0.063
# loudness            -9.974       2.847 -3.914e+00 -1.773e+01     -11.885
# mode                 0.582       0.494  1.000e+00  0.000e+00       0.000
# popularity          44.944      15.098  8.100e+01  6.000e+00      35.000
# speechiness          0.089       0.066  4.200e-01  2.550e-02       0.048
# tempo              113.329      20.054  1.928e+02  7.398e+01     101.467
# valence              0.798       0.151  9.890e-01  2.300e-01       0.735
# danceability         0.726       0.133  9.460e-01  3.030e-01       0.653
#
#                        75%
# time_signature       4.000
# duration_ms     342187.000
# acousticness         0.322
# energy               0.791
# key                  9.000
# liveness             0.236
# loudness            -7.759
# mode                 1.000
# popularity          57.000
# speechiness          0.101
# tempo              119.610
# valence              0.901
# danceability         0.831

# %% [markdown]
# #### Skewness of data

# %%
a._skewness()
# Out:
# time_signature   -10.246
# duration_ms        3.658
# acousticness       1.108
# energy            -0.307
# key               -0.147
# liveness           1.905
# loudness          -0.175
# mode              -0.336
# popularity        -0.188
# speechiness        2.225
# tempo              1.647
# valence           -1.311
# danceability      -0.773
# dtype: float64

# %%
a._skew_plots()

# %% [markdown]
# #### Correlation of selected features

# %%
a._correlation()
# Out:
# The correlation between:
#
# loudness 		 0.594 		 energy
# speechiness 		 0.271 		 liveness
# energy 		 0.594 		 loudness
# liveness 		 0.271 		 speechiness
# danceability 		 0.404 		 valence
# valence 		 0.404 		 danceability

# %% [markdown]
# #### Relationship exploration
# - Relationship between
#     - 'energy' and 'loudness'
#     - 'danceability' and selected features*

# %%
a.relationship_exploration()

# %% [markdown]
# #### Model 1 : SVM Classifier using OneVsRest
# - `Polynomial` fit, degree `2`
# - Probabilistic, tolerance `1e-6`
#     - ROC Evaluation (on `y_test`)

# %%
a.model1()
# Out:
# 0: Not danceable: 14
# 1: Somewhat Danceable 65
# 2: Very Danceable 63
# 3: Extremely Danceable 71
# One-vs-One ROC AUC scores:
# 0.546652 (macro),
# 0.555925 (weighted by prevalence)
# One-vs-Rest ROC AUC scores:
# 0.546652 (macro),
# 0.555925 (weighted by prevalence)

# %% [markdown]
# #### Model 2 : Decision Tree Classifier
# - Default settings
#     - Confusion Matrix Evaluation (on `y_test`)

# %%
a.model2()
# Out:
# 0: Not danceable: 14
# 1: Somewhat Danceable 65
# 2: Very Danceable 63
# 3: Extremely Danceable 71
# Accuracy: 0.36363636363636365
# [[0 0 1 1]
#  [0 2 3 1]
#  [0 3 3 0]
#  [0 1 4 3]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.33      0.33      0.33         6
#            2       0.27      0.50      0.35         6
#            3       0.60      0.38      0.46         8
#
#     accuracy                           0.36        22
#    macro avg       0.30      0.30      0.29        22
# weighted avg       0.38      0.36      0.35        22
#
# Mean Absolute Error: 0.8636363636363636
# Mean Squared Error: 1.4090909090909092
# Root Mean Squared Error: 1.1870513506545997

# %% [markdown]
# #### Model 3 : Multiple Classifiers using k-fold cross validation
# - *Naive Bayes* :
#     - OneVSRest Gaussian Classifier
#         - Default settings
# - *KNN* :
#     - OneVSRest KNeighbour Classifier
#         - `n_neighbors = len(X.columns) + 1`
#         - `metric = 'euclidean'`
#         - `n_jobs = - 1`
#         - `weights = 'distance'`
# - *Bagging* :
#     - OneVSRest Bagging Classifier
#         - Uses `ExtraTreeClassifier`, Default settings
# - *Decision Tree Classifier* :
#     - OneVSRest on top of Decision Tree Classifier
#         - Default settings

# %%
a.model3()
# Out:
# 0: Not danceable: 14
# 1: Somewhat Danceable 65
# 2: Very Danceable 63
# 3: Extremely Danceable 71
# Naive Bayes: 0.41342105263157897 (0.09130062061179937)
# KNN: 0.36631578947368426 (0.09610705019379645)
# Bagging: 0.3557894736842105 (0.07213407031162869)
# Decision Tree: 0.3302631578947368 (0.09819175372002965)
# One-vs-One ROC AUC scores:
# 0.615997 (macro),
# 0.649594 (weighted by prevalence)
# One-vs-Rest ROC AUC scores:
# 0.615997 (macro),
# 0.649594 (weighted by prevalence)
# One-vs-One ROC AUC scores:
# 0.545982 (macro),
# 0.536201 (weighted by prevalence)
# One-vs-Rest ROC AUC scores:
# 0.545982 (macro),
# 0.536201 (weighted by prevalence)
# One-vs-One ROC AUC scores:
# 0.747433 (macro),
# 0.722687 (weighted by prevalence)
# One-vs-Rest ROC AUC scores:
# 0.747433 (macro),
# 0.722687 (weighted by prevalence)
# One-vs-One ROC AUC scores:
# 0.562128 (macro),
# 0.579951 (weighted by prevalence)
# One-vs-Rest ROC AUC scores:
# 0.562128 (macro),
# 0.579951 (weighted by prevalence)
